# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time

# %%
import time

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    client_id=id, client_secret=id))

# %% [markdown]
# ## Adding the playlist

# %%
playlist = spotify.user_playlist_tracks(user="spotify",playlist_id='spotify:playlist:37i9dQZF1EtbkGQVMqstOe')

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# Title

# %%
playlist['items'][0]['track']['name']
# Out:
# 'Dance Monkey'

# %% [markdown]
# ## Artist's uri

# %%
playlist['items'][0]['track']['artists'][0]['uri']
# Out:
# 'spotify:artist:2NjfBq1NflQcKSeiDooVjY'

# %%
artists_list =set()

# %%
artists_list =set()
for item in playlist['items']:
    for artist in item ['track']['artists']:
        artists_list.add(artist['uri'])

# %%
artists_list
# Out:
# {'spotify:artist:06HL4z0CvFAxyc27GXpf02',
#  'spotify:artist:07YUOmWljBTXwIseAUd9TW',
#  'spotify:artist:07YZf4WDAMNwqr4jfgOZ8y',
#  'spotify:artist:09oR0uKhqwScsKa2eUK97p',
#  'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx',
#  'spotify:artist:0EmeFodog0BfCgMzAIvKQp',
#  'spotify:artist:0ZED1XzwlLHW4ZaG4lOT6m',
#  'spotify:artist:0eHQ9o50hj6ZDNBt6Ys1sD',
#  'spotify:artist:0eecdvMrqBftK0M1VKhaF4',
#  'spotify:artist:0haZhu4fFKt0Ag94kZDiz2',
#  'spotify:artist:0tmwSHipWxN12fsoLcFU3B',
#  'spotify:artist:0vR2qb8m9WHeZ5ByCbimq2',
#  'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai',
#  'spotify:artist:1ErIf1pAAaw5upKsCbqhzz',
#  'spotify:artist:1GDbiv3spRmZ1XdM1jQbT7',
#  'spotify:artist:1HBjj22wzbscIZ9sEb5dyf',
#  'spotify:artist:1HY2Jd0NmPuamShAr6KMms',
#  'spotify:artist:1KCSPY1glIKqW2TotWuXOR',
#  'spotify:artist:1L9i6qZYIGQedgM9QLSyzb',
#  'spotify:artist:1PnnRNGfichOAfPOn5mVyx',
#  'spotify:artist:1SupJlEpv7RS2tPNRaHViT',
#  'spotify:artist:1TcbdifqhtxLz77unBYJ7z',
# ...

# %% [markdown]
# ## Albums uri

# %%
albums = spotify.artist_albums(artist_id='spotify:artist:2NjfBq1NflQcKSeiDooVjY')

# %%
albums['items'][0]['uri']
# Out:
# 'spotify:album:4cZnf6t6wb8ZyYN7PiLKh2'

# %%
albums_list = set()

# %%
albums_list = set()
for item in albums['items']:
    albums_list.add(item['uri'])

# %%
albums_list
# Out:
# {'spotify:album:0UywfDKYlyiu1b38DRrzYD',
#  'spotify:album:0ZrEytwQc2Oj53GcBm8bEB',
#  'spotify:album:1BYByciKxjYwhRSrWlEjWu',
#  'spotify:album:2WSnuau1j8jGUrrCvRo8rK',
#  'spotify:album:2pJXQvY0YeDvVJ9gMU9G7j',
#  'spotify:album:31IDBea3eEs57a0joX6TjN',
#  'spotify:album:3BL6Tm6PF0S7gDbZnu1u5D',
#  'spotify:album:3Brtanx0kPabTenDcmang1',
#  'spotify:album:49QPpqyxeTbzWHUJpZuUsC',
#  'spotify:album:4cZnf6t6wb8ZyYN7PiLKh2',
#  'spotify:album:4d3lSZl0S700hBd34vyH0s',
#  'spotify:album:4ozuVdO3D8DSLq6TVwz2JK',
#  'spotify:album:5DHaCppf6pg4GmqUkqdSJh',
#  'spotify:album:5fWGZ7dAPYdMslAjrPqfeQ',
#  'spotify:album:6MX2RQGxwnKc0iGlxTaWoS',
#  'spotify:album:6Z7DGRyzIlsq7kXNXQF3Yd',
#  'spotify:album:7aIB4rIz3aSCk2hxfVLhy7',
#  'spotify:album:7eXkoxpwv6Jugkv2o1nlyR',
#  'spotify:album:7oVHtPdIA5kcxLLiCu2t7N',
#  'spotify:album:7xXGPdbrUMXClnSMOIdTlW'}

# %% [markdown]
# ## Songs from the album uri

# %%
songs = spotify.album_tracks(album_id='spotify:album:2pJXQvY0YeDvVJ9gMU9G7j')

# %%
songs['items'][1]['uri']
# Out:
# 'spotify:track:5ZULALImTm80tzUbYQYM9d'

# %%
songs_list=set()

# %%
songs_list=set()
for song in songs['items']:
    songs_list.add(song['uri'])

# %%
songs_list
# Out:
# {'spotify:track:0JQ5MbyriK6ruD3t6RZ7ix',
#  'spotify:track:4kRT3cCwp0uYEqh4hHvxZS',
#  'spotify:track:5ZULALImTm80tzUbYQYM9d',
#  'spotify:track:5fmBkJa4mTezkJq8B1TgSn',
#  'spotify:track:76bvw5EDyhm1b3dfsOToYG',
#  'spotify:track:7BooBD8k8ABLTFLzgxcT5G'}

# %%
import pandas as pd

# %%
spotify.audio_features('spotify:track:0JQ5MbyriK6ruD3t6RZ7ix')
# Out:
# [{'danceability': 0.672,
#   'energy': 0.464,
#   'key': 6,
#   'loudness': -5.624,
#   'mode': 0,
#   'speechiness': 0.037,
#   'acousticness': 0.43,
#   'instrumentalness': 0,
#   'liveness': 0.284,
#   'valence': 0.271,
#   'tempo': 92.069,
#   'type': 'audio_features',
#   'id': '0JQ5MbyriK6ruD3t6RZ7ix',
#   'uri': 'spotify:track:0JQ5MbyriK6ruD3t6RZ7ix',
#   'track_href': 'https://api.spotify.com/v1/tracks/0JQ5MbyriK6ruD3t6RZ7ix',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JQ5MbyriK6ruD3t6RZ7ix',
#   'duration_ms': 200742,
#   'time_signature': 4}]

# %%
x = spotify.audio_features('spotify:track:0JQ5MbyriK6ruD3t6RZ7ix')

# %%
z = pd.DataFrame(x)

# %%
z
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.672   0.464    6    -5.624     0        0.037          0.43
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0                 0     0.284    0.271  92.069  audio_features
#
#                        id                                   uri  \
# 0  0JQ5MbyriK6ruD3t6RZ7ix  spotify:track:0JQ5MbyriK6ruD3t6RZ7ix
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0JQ5MbyriK6r...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0JQ5...       200742
#
#    time_signature
# 0               4

# %% [markdown]
# # Artists to albums

# %%
artists_list
# Out:
# {'spotify:artist:06HL4z0CvFAxyc27GXpf02',
#  'spotify:artist:07YUOmWljBTXwIseAUd9TW',
#  'spotify:artist:07YZf4WDAMNwqr4jfgOZ8y',
#  'spotify:artist:09oR0uKhqwScsKa2eUK97p',
#  'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx',
#  'spotify:artist:0EmeFodog0BfCgMzAIvKQp',
#  'spotify:artist:0ZED1XzwlLHW4ZaG4lOT6m',
#  'spotify:artist:0eHQ9o50hj6ZDNBt6Ys1sD',
#  'spotify:artist:0eecdvMrqBftK0M1VKhaF4',
#  'spotify:artist:0haZhu4fFKt0Ag94kZDiz2',
#  'spotify:artist:0tmwSHipWxN12fsoLcFU3B',
#  'spotify:artist:0vR2qb8m9WHeZ5ByCbimq2',
#  'spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai',
#  'spotify:artist:1ErIf1pAAaw5upKsCbqhzz',
#  'spotify:artist:1GDbiv3spRmZ1XdM1jQbT7',
#  'spotify:artist:1HBjj22wzbscIZ9sEb5dyf',
#  'spotify:artist:1HY2Jd0NmPuamShAr6KMms',
#  'spotify:artist:1KCSPY1glIKqW2TotWuXOR',
#  'spotify:artist:1L9i6qZYIGQedgM9QLSyzb',
#  'spotify:artist:1PnnRNGfichOAfPOn5mVyx',
#  'spotify:artist:1SupJlEpv7RS2tPNRaHViT',
#  'spotify:artist:1TcbdifqhtxLz77unBYJ7z',
# ...

# %%
albums = spotify.artist_albums(artist_id='spotify:artist:2NjfBq1NflQcKSeiDooVjY')

# %%
albums_list = set()
for item in albums['items']:
    albums_list.add(item['uri'])
    
albums_list
# Out:
# {'spotify:album:0UywfDKYlyiu1b38DRrzYD',
#  'spotify:album:0ZrEytwQc2Oj53GcBm8bEB',
#  'spotify:album:1BYByciKxjYwhRSrWlEjWu',
#  'spotify:album:2WSnuau1j8jGUrrCvRo8rK',
#  'spotify:album:2pJXQvY0YeDvVJ9gMU9G7j',
#  'spotify:album:31IDBea3eEs57a0joX6TjN',
#  'spotify:album:3BL6Tm6PF0S7gDbZnu1u5D',
#  'spotify:album:3Brtanx0kPabTenDcmang1',
#  'spotify:album:49QPpqyxeTbzWHUJpZuUsC',
#  'spotify:album:4cZnf6t6wb8ZyYN7PiLKh2',
#  'spotify:album:4d3lSZl0S700hBd34vyH0s',
#  'spotify:album:4ozuVdO3D8DSLq6TVwz2JK',
#  'spotify:album:5DHaCppf6pg4GmqUkqdSJh',
#  'spotify:album:5fWGZ7dAPYdMslAjrPqfeQ',
#  'spotify:album:6MX2RQGxwnKc0iGlxTaWoS',
#  'spotify:album:6Z7DGRyzIlsq7kXNXQF3Yd',
#  'spotify:album:7aIB4rIz3aSCk2hxfVLhy7',
#  'spotify:album:7eXkoxpwv6Jugkv2o1nlyR',
#  'spotify:album:7oVHtPdIA5kcxLLiCu2t7N',
#  'spotify:album:7xXGPdbrUMXClnSMOIdTlW'}

# %%
albums =[]
for artist in artists_list:
    albums.append(spotify.artist_albums(artist_id = artist))

# %%
albums[0]['items'][0]['uri']
# Out:
# 'spotify:album:4BvD9caT3ZohqNQFcR8dVD'

# %% [markdown]
# This si the final from artist to albums

# %%
albums_list = set()
for album in albums:
    for item in album['items']:
        albums_list.add(item['uri'])

# %%
albums_list
# Out:
# {'spotify:album:0EnyJALCORJdl4KR1ItWk3',
#  'spotify:album:5oXBmKbyJeQftWMo87cQ9F',
#  'spotify:album:4GRujL5dgx7WQQcvjbVcfG',
#  'spotify:album:18om9SClbLznT7O8ofSVId',
#  'spotify:album:1Z0XtKcevvITZ5ydimkYcx',
#  'spotify:album:1HLBpz1LijH2GD2Um5vemj',
#  'spotify:album:3Cp0sakxj4DSP6GugPcgkR',
#  'spotify:album:2PVHMJyVVuVgDfOH47PNRE',
#  'spotify:album:1c7u7kI8UHayM4kHQua6qI',
#  'spotify:album:1Q9ij11CdNvogM0IPG1KNc',
#  'spotify:album:4uof2ZG6R07HdpkYBtPhV8',
#  'spotify:album:6gLmdzR4hAdr8jIquzZHqH',
#  'spotify:album:36rPPcwcImUfUmll4PxX7T',
#  'spotify:album:2ygDna5MDlGDQQPW5iD4RD',
#  'spotify:album:1txuOfi9mdPknKxxJMw6PW',
#  'spotify:album:4BvD9caT3ZohqNQFcR8dVD',
#  'spotify:album:4w7X6ojBPCALJIII9GcXt6',
#  'spotify:album:69Onmm7lXVzZMZoYXSJFiv',
#  'spotify:album:1MAJSLjUeB6OzsEdVv9Iqa',
#  'spotify:album:1DlMxHYECRDP7FmXLpKRRv',
#  'spotify:album:5hHBkqV6gED9WKE6qr0DfP',
#  'spotify:album:1HtmKNFx5Lpv2wxNH9to5d',
#  'spotify:album:67wcx7UfDpz2zcAWZJHLQd',
# ...

# %% [markdown]
# # Albums to songs

# %%
songs = spotify.album_tracks(album_id='spotify:album:2pJXQvY0YeDvVJ9gMU9G7j')

# %%
songs_list=set()
for song in songs['items']:
    songs_list.add(song['uri'])

# %%
songs =[]
for album in albums_list:
    songs.append(spotify.album_tracks(album_id=album))

# %%
songs_list=set()
for song in songs:
    for item in song['items']:
        songs_list.add(item['uri'])

# %%
len(songs_list)
# Out:
# 19886

# %% [markdown]
# ## Sum

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(
    client_id="f427c27f15b8441a8122e307a960d011", client_secret="3b924a72bef446f2ad8ba21032c5bcbb"))

# %%
playlist = spotify.user_playlist_tracks(user="spotify",playlist_id='spotify:playlist:21lNm0jzMQe085B2VxnhcB')

# %%
#List of artists
artists_list =set()
for item in playlist['items']:
    for artist in item ['track']['artists']:
        artists_list.add(artist['uri'])

# %%
# From  artist to album
albums =[]
for artist in artists_list:
    albums.append(spotify.artist_albums(artist_id = artist))
    
albums_list = set()
for album in albums:
    for item in album['items']:
        albums_list.add(item['uri'])

# %%
#From album to song
songs =[]
for album in albums_list:
    songs.append(spotify.album_tracks(album_id=album))

songs_list=set()
for song in songs:
    for item in song['items']:
        songs_list.add(item['uri'])

# %%
print(len(songs_list))
# Out:
# 7412

# %%
songs_list
# Out:
# {'spotify:track:10Hb1MlXsnI7Yi936C97NA',
#  'spotify:track:1aRf5VSmSWdXnDgimeGft2',
#  'spotify:track:2yTGvV6yAiDNhwNFZ1R35r',
#  'spotify:track:3HPvXWekjDqIppRxhpHkDT',
#  'spotify:track:2B715gmGTtpeXJCEkcZnbS',
#  'spotify:track:7BPw9h8vCIX94N0rjFU12S',
#  'spotify:track:4RNreqLjMc6jWRkR1zSBJ0',
#  'spotify:track:5DCRyi6yFz3A0NrCOEisRg',
#  'spotify:track:4Kn15ItF8lF76fir53Rzux',
#  'spotify:track:009ImBOrIUlWgla8U05RAC',
#  'spotify:track:2GGlmWRIXQaVkPQwCWZlmf',
#  'spotify:track:2NY5X8moaF5CvQpQvwgj5O',
#  'spotify:track:0zm4vwO41gxrHE9DUD4WXP',
#  'spotify:track:7jpSvCrFev9EBb5RSmoRTa',
#  'spotify:track:2fahrw6cLsUzaxexhMHLqa',
#  'spotify:track:0QRxJvOohS8yiGC1n98uFM',
#  'spotify:track:6sMnVgvZjlwEUsIHMYzMIp',
#  'spotify:track:59HA1SBz1DPCCvdDeILV7E',
#  'spotify:track:5VhdgfcdN45DpObVXkmzXl',
#  'spotify:track:77RouGS483BT5rRaFdqjh8',
#  'spotify:track:7oMNEvH2JclzqmrE4VqDzT',
#  'spotify:track:6bNxzYcV6ozN5WotgkTe1O',
#  'spotify:track:295WSaPVlJ52FywcpYJqqT',
# ...

# %%
songs_list=['spotify:track:10Hb1MlXsnI7Yi936C97NA',
 'spotify:track:1aRf5VSmSWdXnDgimeGft2',
 'spotify:track:2yTGvV6yAiDNhwNFZ1R35r',
 'spotify:track:3HPvXWekjDqIppRxhpHkDT',
 'spotify:track:2B715gmGTtpeXJCEkcZnbS',
 'spotify:track:7BPw9h8vCIX94N0rjFU12S',
 'spotify:track:4RNreqLjMc6jWRkR1zSBJ0',
 'spotify:track:5DCRyi6yFz3A0NrCOEisRg',
 'spotify:track:4Kn15ItF8lF76fir53Rzux',
 'spotify:track:009ImBOrIUlWgla8U05RAC',
 'spotify:track:2GGlmWRIXQaVkPQwCWZlmf',
 'spotify:track:2NY5X8moaF5CvQpQvwgj5O',
 'spotify:track:0zm4vwO41gxrHE9DUD4WXP',
 'spotify:track:7jpSvCrFev9EBb5RSmoRTa',
 'spotify:track:2fahrw6cLsUzaxexhMHLqa',
 'spotify:track:0QRxJvOohS8yiGC1n98uFM',
 'spotify:track:6sMnVgvZjlwEUsIHMYzMIp',
 'spotify:track:59HA1SBz1DPCCvdDeILV7E',
 'spotify:track:5VhdgfcdN45DpObVXkmzXl',
 'spotify:track:77RouGS483BT5rRaFdqjh8',
 'spotify:track:7oMNEvH2JclzqmrE4VqDzT',
 'spotify:track:6bNxzYcV6ozN5WotgkTe1O',
 'spotify:track:295WSaPVlJ52FywcpYJqqT',
 'spotify:track:7oov1MyIOa1IIi0gcAsDNZ',
 'spotify:track:1F95szeWXijgHApSXw2coB',
 'spotify:track:1Z79tpetXTqujnp0UYOV7V',
 'spotify:track:27HJWxvlneV5hBzCSRSl5b',
 'spotify:track:0u3JbqLsm8fZwtphkhCUSA',
 'spotify:track:2nEJjSTDYm2kYzOmj2CG6k',
 'spotify:track:14Yjnh0oSqwW7725JfUDuy',
 'spotify:track:2bzitsPcImYC6DZWvvLCQi',
 'spotify:track:4UXttQzKHWa0h385GDvXj8',
 'spotify:track:1TeDbA2Hfy14sEjoUvZ8Pa',
 'spotify:track:1ZN2K6cHnf4ibuqP6WfQgp',
 'spotify:track:3OPEx1SY3wkDCKLeQ56tyN',
 'spotify:track:7tKOCWlyhaHyhnmqvJjLSl',
 'spotify:track:1vZgVMF6uAaghB0qZxyGuP',
 'spotify:track:1aufVYjIKcrXfEv2rYlzrZ',
 'spotify:track:79VmQuOW9aVJgydOwSWEH8',
 'spotify:track:18jCn9DISROy7aHfmLvj9I',
 'spotify:track:6N5AHT8QC7Vonfjf3hLuLF',
 'spotify:track:2tnlEoEp3vdopjKieNiXVp',
 'spotify:track:07FNUi1pPMjZ4FEHi6HYdj',
 'spotify:track:4bfaHld2OHIKgIzc6sku6T',
 'spotify:track:4igcuXGXmK0BMYbiK5cF2i',
 'spotify:track:0F6EBotfgEH94IePMhEeAh',
 'spotify:track:23lnmTzsTFNihOdBZ0Cfmy',
 'spotify:track:3QNcGTHxCCLoHWKIake7x4',
 'spotify:track:5PSOWHll3h3Vy226xSJk0M',
 'spotify:track:3dU0IkXaxwxVe9vFSGvSd3',
 'spotify:track:0Kc8WAHOLxt7VdHh8UkeN5',
 'spotify:track:5wjYNruCFPyg3EBW2sAVw2',
 'spotify:track:3eVmi1hFMMrbeKNrFdBNZk',
 'spotify:track:2QSuNcQxqFfokvbS7SInHG',
 'spotify:track:1SwxqNEztrhIolJYhjcaco',
 'spotify:track:3030YT1OMJa4bxthLLHuVM',
 'spotify:track:4NiehSBQthimPzRsVeOgCT',
 'spotify:track:7yJzk64ul9PFgVFUYbEzZL',
 'spotify:track:0woTViKE066rw7WJBPcsc0',
 'spotify:track:29TpL9ws8zoA733eOXa9cm',
 'spotify:track:54mIMbtBXXGi1XjdXHN81j',
 'spotify:track:07SHlyJJ5iwhlkffdYjXyG',
 'spotify:track:1KEFvunr3klXAhldlXePcA',
 'spotify:track:24lpbjvTMZBPLaTmifBDnL',
 'spotify:track:0Q02BUrNVSXLOeuLCvMlJZ',
 'spotify:track:1YRqcHp1bIw3ca3KiKxQqY',
 'spotify:track:3512ZABQmQMoa7Y34j7qI7',
 'spotify:track:5ljRYlklaEdK2BQaxJG5S8',
 'spotify:track:0pNryfJKWJfiPV7DVJQRWz',
 'spotify:track:6CyKXBfcqpoCBh4yRvoNyK',
 'spotify:track:5nGuzcsjDbUD1Hgi0szupA',
 'spotify:track:3bwRblhAbbkQ8GoL7YatI7',
 'spotify:track:3BuVuO5N3ySxJJLNY4Y4ya',
 'spotify:track:5l32eCfB79Q5kYIMIq1xqG',
 'spotify:track:1OTXnoe2AGsDQ3Yp1vxI9s',
 'spotify:track:0NlYBIdX1wt6ibV3d1O4fV',
 'spotify:track:3pJvqRidCb1OwEmDx0g8fA',
 'spotify:track:55shd4rVS4I7wkKQ2H63QJ',
 'spotify:track:2Hta8eWFWdyKskJ1LosAlM',
 'spotify:track:04lOQCVFeS7QQfWZjmLAr5',
 'spotify:track:4cxLOSgpuWGYAcySrgtRe4',
 'spotify:track:1nvSkSotv0PoHX10tBDYlM',
 'spotify:track:5OIarNZ0GKz9bch7dYVxsr',
 'spotify:track:6dJPqP0gHP6iAZuIk1njBs',
 'spotify:track:1likxiGuFOCkY2WtGbHj3F',
 'spotify:track:2QM9J02L4iUqScO9UG0iB2',
 'spotify:track:4E3tu3aBqa2enofXenoTJK',
 'spotify:track:3Be7CLdHZpyzsVijme39cW',
 'spotify:track:0bADLTzw5zaGH03Raxid8U',
 'spotify:track:07r2mkoLnUFpMqZ2M8xdNo',
 'spotify:track:0pQoNBSZeRFuhLVH8gCVDT',
 'spotify:track:5TtWW4567WCd8MSTpUd5wt',
 'spotify:track:2ExJEiXzBdVTDt5WRxglgu',
 'spotify:track:7HCnuwV7xCMfqljSUcgGci',
 'spotify:track:57yHXTSZDdvYfmhvq8oA3m',
 'spotify:track:0cLMUdJzv9bxmxZGfqcmoB',
 'spotify:track:2nx2R0mddGuRiv60NsjeAU',
 'spotify:track:6P8j2SqbXOeaCvXh1ZXwWT',
 'spotify:track:4FLRw7sFTaKX66TKAHDstv',
 'spotify:track:2Ml0l8YWJLQhPrRDLpQaDM']

# %%
len(songs_list)
# Out:
# 100

# %%
features_all=[]
for songs in songs_list:
    features_all.append(spotify.audio_features(songs))

# %%
features_all[0][0].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
features_all[0]
# Out:
# [{'danceability': 0.709,
#   'energy': 0.794,
#   'key': 7,
#   'loudness': -2.867,
#   'mode': 1,
#   'speechiness': 0.0526,
#   'acousticness': 0.00137,
#   'instrumentalness': 0.000104,
#   'liveness': 0.14,
#   'valence': 0.681,
#   'tempo': 110.012,
#   'type': 'audio_features',
#   'id': '10Hb1MlXsnI7Yi936C97NA',
#   'uri': 'spotify:track:10Hb1MlXsnI7Yi936C97NA',
#   'track_href': 'https://api.spotify.com/v1/tracks/10Hb1MlXsnI7Yi936C97NA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10Hb1MlXsnI7Yi936C97NA',
#   'duration_ms': 264173,
#   'time_signature': 4}]

# %%
len(features_all)
# Out:
# 100

# %% [markdown]
# # This is the good one!!!!!

# %%
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans 
import numpy as np
import random

# %%
X = pd.DataFrame(features_all[0], columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'])

# %%
for i in range(1,len(features_all)):
    X = X.append(pd.DataFrame((features_all[i]), columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']),ignore_index=True)

# %%
X
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.709   0.794    7    -2.867     1       0.0526      0.001370
# 1          0.597   0.746   10    -8.448     1       0.0623      0.060000
# 2          0.366   0.324    3   -16.698     1       0.0370      0.933000
# 3          0.588   0.428    9    -6.834     0       0.0310      0.499000
# 4          0.547   0.718    0    -4.569     1       0.0335      0.000514
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.390   0.671    4    -7.570     1       0.0386      0.192000
# 96         0.651   0.529    0   -12.251     1       0.0352      0.073500
# 97         0.624   0.691    0    -6.686     0       0.1960      0.060400
# 98         0.638   0.826    8    -4.968     1       0.0479      0.139000
# 99         0.694   0.711    0    -4.237     1       0.0517      0.114000
#
#     instrumentalness  liveness  valence    tempo
# ...

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(X)
# Out:
# array([[ 0.57104408,  0.75434262,  0.5817091 , ..., -0.33450861,
#          0.78974597, -0.44879049],
#        [-0.11232954,  0.51942116,  1.43716367, ...,  3.43428574,
#         -0.43424469,  0.2387553 ],
#        [-1.52178764, -1.54593009, -0.55889698, ...,  3.04811875,
#         -1.23023861,  0.28040374],
#        ...,
#        [ 0.05241232,  0.25024031, -1.41435155, ..., -0.34428499,
#         -0.79824191,  1.47627612],
#        [ 0.13783402,  0.91095694,  0.86686062, ..., -0.62633354,
#          0.66174695,  0.09240836],
#        [ 0.47952083,  0.34812425, -1.41435155, ..., -0.80719656,
#          1.96173703, -0.08296163]])

# %%
X_scaled = scaler.fit_transform(X)

# %%
pd.DataFrame(X_scaled)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.571044  0.754343  0.581709  1.293730  0.670280 -0.312611 -0.814713
# 1  -0.112330  0.519421  1.437164 -0.244456  0.670280 -0.228503 -0.581690
# 2  -1.521788 -1.545930 -0.558897 -2.518248  0.670280 -0.447876  2.888024
# 3  -0.167243 -1.036934  1.152012  0.200380 -1.491914 -0.499901  1.163103
# 4  -0.417407  0.382384 -1.414352  0.824640  0.670280 -0.478224 -0.818115
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -1.375350  0.152356 -0.273745 -0.002469  0.670280 -0.434003 -0.057059
# 96  0.217154 -0.542620 -1.414352 -1.292605  0.670280 -0.463484 -0.528034
# 97  0.052412  0.250240 -1.414352  0.241171 -1.491914  0.930792 -0.580100
# 98  0.137834  0.910957  0.866861  0.714671  0.670280 -0.353364 -0.267706
# 99  0.479521  0.348124 -1.414352  0.916142  0.670280 -0.320415 -0.367068
#
#           7         8         9         10
# 0  -0.348565 -0.334509  0.789746 -0.448790
# ...

# %%
kmeans = KMeans(n_clusters=8, random_state=1234)

# %%
kmeans.fit(X_scaled) # with this the model is fitted
# Out:
# KMeans(random_state=1234)

# %%
#kmeans.predict(X_scaled)

# %%
clusters = kmeans.predict(X_scaled) #####this is what i need for the single song

# %%
clusters
# Out:
# array([4, 0, 0, 6, 2, 1, 7, 3, 1, 6, 6, 4, 0, 6, 6, 0, 3, 3, 1, 1, 3, 6,
#        4, 7, 4, 5, 4, 4, 4, 4, 2, 4, 2, 4, 4, 2, 4, 1, 3, 2, 6, 3, 1, 3,
#        6, 4, 6, 2, 2, 1, 7, 4, 4, 1, 1, 2, 2, 4, 7, 2, 6, 6, 1, 6, 0, 0,
#        2, 2, 1, 4, 1, 7, 6, 7, 5, 1, 0, 4, 2, 1, 2, 7, 2, 6, 4, 1, 3, 1,
#        3, 6, 4, 2, 4, 1, 4, 0, 7, 6, 4, 4], dtype=int32)

# %%
pd.Series(clusters).value_counts()
# Out:
# 4    24
# 1    17
# 6    16
# 2    16
# 3     9
# 7     8
# 0     8
# 5     2
# dtype: int64

# %% [markdown]
# ## my song

# %%
features_input_song = [{'danceability': 0.648, 'energy': 0.785, 'key': 7, 'loudness': -5.414, 'mode': 1, 'speechiness': 0.165, 'acousticness': 0.0561, 'instrumentalness': 0, 'liveness': 0.148, 'valence': 0.943, 'tempo': 160.02, 'type': 'audio_features', 'id': '5xTtaWoae3wi06K5WfVUUH', 'uri': 'spotify:track:5xTtaWoae3wi06K5WfVUUH', 'track_href': 'https://api.spotify.com/v1/tracks/5xTtaWoae3wi06K5WfVUUH', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5xTtaWoae3wi06K5WfVUUH', 'duration_ms': 219200, 'time_signature': 4}]

# %%
df_input_song = pd.DataFrame(features_input_song, columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'])

# %%
df_input_song
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.648   0.785    7    -5.414     1        0.165        0.0561
#
#    instrumentalness  liveness  valence   tempo
# 0                 0     0.148    0.943  160.02

# %%
song_scaled = scaler.transform(df_input_song)

# %%
song_scaled
# Out:
# array([[ 0.19884952,  0.71029485,  0.5817091 ,  0.59174811,  0.67028006,
#          0.66199467, -0.59718994, -0.34901013, -0.29540309,  1.83773798,
#          1.47612215]])

# %%
kmeans.predict(song_scaled)
# Out:
# array([4], dtype=int32)

# %%
clust = int(kmeans.predict(song_scaled))

# %%
clust
# Out:
# 4

# %%
X["clusters"] = clusters

# %%
X
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.709   0.794    7    -2.867     1       0.0526      0.001370
# 1          0.597   0.746   10    -8.448     1       0.0623      0.060000
# 2          0.366   0.324    3   -16.698     1       0.0370      0.933000
# 3          0.588   0.428    9    -6.834     0       0.0310      0.499000
# 4          0.547   0.718    0    -4.569     1       0.0335      0.000514
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.390   0.671    4    -7.570     1       0.0386      0.192000
# 96         0.651   0.529    0   -12.251     1       0.0352      0.073500
# 97         0.624   0.691    0    -6.686     0       0.1960      0.060400
# 98         0.638   0.826    8    -4.968     1       0.0479      0.139000
# 99         0.694   0.711    0    -4.237     1       0.0517      0.114000
#
#     instrumentalness  liveness  valence    tempo  clusters
# ...

# %%
X["id"] = X.index

# %%
X[X["clusters"] == clust]
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.709   0.794    7    -2.867     1       0.0526       0.00137
# 11         0.779   0.934    3    -2.027     1       0.1890       0.02360
# 22         0.726   0.945    7    -3.591     1       0.0700       0.00183
# 24         0.748   0.788    1    -7.055     1       0.0334       0.05910
# 26         0.755   0.802    9    -6.418     1       0.0551       0.03600
# 27         0.842   0.819    1    -6.803     1       0.1340       0.07480
# 28         0.755   0.855    7    -3.381     1       0.0278       0.37000
# 29         0.843   0.629    7    -5.811     1       0.0479       0.00507
# 31         0.701   0.787    8    -6.428     1       0.2520       0.14400
# 33         0.734   0.703    1   -10.892     1       0.1110       0.09780
# 34         0.605   0.725    5    -5.729     1       0.0323       0.00201
# 36         0.590   0.869    9    -3.835     1       0.1100       0.00948
# ...

# %%
list1 = (X[X["clusters"] == clust]["id"].values).tolist()

# %%
list1
# Out:
# [0,
#  11,
#  22,
#  24,
#  26,
#  27,
#  28,
#  29,
#  31,
#  33,
#  34,
#  36,
#  45,
#  51,
#  52,
#  57,
#  69,
#  77,
#  84,
#  90,
#  92,
#  94,
#  98,
#  99]

# %%
rand_song = random.choice(list1)

# %%
new_song_uri = songs_list[rand_song]

# %%
spotify.track(new_song_uri)['name']
# Out:
# 'Blame It On The Stars'

# %%
spotify.track(new_song_uri)['artists'][0]['name']
# Out:
# 'Andy Grammer'

# %%
input_s = [{'danceability': 0.392, 'energy': 0.402, 'key': 0, 'loudness': -9.961, 'mode': 0, 'speechiness': 0.0536, 'acousticness': 0.288, 'instrumentalness': 0, 'liveness': 0.243, 'valence': 0.228, 'tempo': 143.883, 'type': 'audio_features', 'id': '7tFiyTwD0nx5a1eklYtX2J', 'uri': 'spotify:track:7tFiyTwD0nx5a1eklYtX2J', 'track_href': 'https://api.spotify.com/v1/tracks/7tFiyTwD0nx5a1eklYtX2J', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tFiyTwD0nx5a1eklYtX2J', 'duration_ms': 354320, 'time_signature': 4}]

# %%
import time

# %%
features_input_song =  [{'danceability': 0.392, 'energy': 0.402, 'key': 0, 'loudness': -9.961, 'mode': 0, 'speechiness': 0.0536, 'acousticness': 0.288, 'instrumentalness': 0, 'liveness': 0.243, 'valence': 0.228, 'tempo': 143.883, 'type': 'audio_features', 'id': '7tFiyTwD0nx5a1eklYtX2J', 'uri': 'spotify:track:7tFiyTwD0nx5a1eklYtX2J', 'track_href': 'https://api.spotify.com/v1/tracks/7tFiyTwD0nx5a1eklYtX2J', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tFiyTwD0nx5a1eklYtX2J', 'duration_ms': 354320, 'time_signature': 4}]

# %%
features_input_song =  [{'danceability': 0.747, 'energy': 0.492, 'key': 10, 'loudness': -9.616, 'mode': 1, 'speechiness': 0.04, 'acousticness': 0.0163, 'instrumentalness': 0.00897, 'liveness': 0.224, 'valence': 0.533, 'tempo': 119.531, 'type': 'audio_features', 'id': '2PzCOP5Aj9SABiBgNEZ52G', 'uri': 'spotify:track:2PzCOP5Aj9SABiBgNEZ52G', 'track_href': 'https://api.spotify.com/v1/tracks/2PzCOP5Aj9SABiBgNEZ52G', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2PzCOP5Aj9SABiBgNEZ52G', 'duration_ms': 292571, 'time_signature': 4}]

# %% [markdown]
# # Song recommender - Spotify

# %% [markdown]
# Give me a song title: Gimme Gimme
#
# Hope this is what you meant:  Gimme! Gimme! Gimme! (A Man After Midnight) from  ABBA
#
# It's not a hot song...

# %%
df_input_song = pd.DataFrame(features_input_song, columns=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'])

#get the scale and cluster
song_scaled = scaler.transform(df_input_song)
kmeans.predict(song_scaled)
clust = int(kmeans.predict(song_scaled))

#get the list of songs from the same cluster randomly
list1 = (X[X["clusters"] == clust]["id"].values).tolist()
new_song_uri = songs_list[random.choice(list1)]

print("Here is a special recommendation for you: " ,spotify.track(new_song_uri)['name'], "from", spotify.track(new_song_uri)['artists'][0]['name'])
print("\n")
time.sleep(2)
print("Hope you liked our recommendation and we will see you soon!")
# Out:
# Here is a special recommendation for you:  Honey, I'm Good. from Andy Grammer
#
#
# Hope you liked our recommendation and we will see you soon!
